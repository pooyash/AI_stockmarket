# %%
import matplotlib.pyplot as plt

# Model names and their corresponding accuracies
model_names = [
    'Random Forest (Initial)',
    'Random Forest (Improved)',
    'CNN + LSTM',
    'Autoencoder + MLP',
    'XGBoost (Initial)',
    'XGBoost (With PCA)',
    'Stacking Model (Supervised)',
    'Stacking Model (Semi-Supervised)'
]

accuracies = [
    0.5299,  # Random Forest (Initial)
    0.6141,  # Random Forest (Improved)
    0.3950,  # CNN + LSTM
    0.3857,  # Autoencoder + MLP
    0.3400,  # XGBoost (Initial)
    0.6539,  # XGBoost (With PCA)
    0.9900,  # Stacking Model (Supervised)
    0.9529   # Stacking Model (Semi-Supervised)
]

# Plotting a bar chart to compare model accuracies
plt.figure(figsize=(12, 6))
plt.barh(model_names, accuracies, color='skyblue')
plt.xlabel('Accuracy')
plt.title('Comparison of Model Accuracies')
plt.xlim(0, 1)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Importing necessary libraries
import pandas as pd
from IPython.display import display

# Creating a DataFrame for the classification report without the 'Support' column
classification_data_revised = {
    'Class': [
        'BEARISH ENGULFING', 'BULLISH ENGULFING', 'DARK CLOUD COVER', 'DOJI',
        'Dragonfly Doji', 'EVENING DOJI STAR', 'EVENING STAR', 'Gravestone Doji',
        'HAMMER', 'HANGING MAN', 'INVERTED HAMMER', 'MORNING DOJI STAR',
        'MORNING STAR', 'PIERCING LINE', 'SHOOTING STAR', 'SPINNING TOP',
        'THREE BLACK CROWS', 'THREE WHITE SOLDIERS', 'Unknown'
    ],
    'Precision': [
        1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00,
        1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 0.98
    ],
    'Recall': [
        0.93, 1.00, 0.98, 0.98, 1.00, 1.00, 1.00, 1.00, 0.75, 1.00, 1.00,
        1.00, 1.00, 1.00, 1.00, 0.99, 1.00, 1.00, 1.00
    ],
    'F1-Score': [
        0.97, 1.00, 0.99, 0.99, 1.00, 1.00, 1.00, 1.00, 0.86, 1.00, 1.00,
        1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 1.00, 0.99
    ]
}

# Creating the DataFrame without 'Support'
classification_df_revised = pd.DataFrame(classification_data_revised)

# Displaying the DataFrame in a Jupyter Notebook or similar environment
display(classification_df_revised)

# Alternatively, print the DataFrame to the console
print(classification_df_revised)

# Optional: Save the DataFrame to a CSV file for further use
classification_df_revised.to_csv("classification_report.csv", index=False)
# Out:
#                    Class  Precision  Recall  F1-Score
# 0      BEARISH ENGULFING       1.00    0.93      0.97
# 1      BULLISH ENGULFING       1.00    1.00      1.00
# 2       DARK CLOUD COVER       1.00    0.98      0.99
# 3                   DOJI       1.00    0.98      0.99
# 4         Dragonfly Doji       1.00    1.00      1.00
# 5      EVENING DOJI STAR       1.00    1.00      1.00
# 6           EVENING STAR       1.00    1.00      1.00
# 7        Gravestone Doji       1.00    1.00      1.00
# 8                 HAMMER       1.00    0.75      0.86
# 9            HANGING MAN       1.00    1.00      1.00
# 10       INVERTED HAMMER       1.00    1.00      1.00
# 11     MORNING DOJI STAR       1.00    1.00      1.00
# 12          MORNING STAR       1.00    1.00      1.00
# 13         PIERCING LINE       1.00    1.00      1.00
# 14         SHOOTING STAR       1.00    1.00      1.00
# 15          SPINNING TOP       1.00    0.99      1.00
# ...
